# %% [markdown]
# <a href="https://colab.research.google.com/github/vipulcvaru/SoftwareLAB/blob/main/IR_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
ps = PorterStemmer()

# %%
#nltk.download('wordnet')
#nltk.download('punkt')
#nltk.download('stopwords')

# %%
text = ""
with open("/content/RL.txt") as file:
  for line in file:
    text += line

# %%
line
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-72d3ca21d17d> in <cell line: 1>()
# ----> 1 line
#       2
#
# NameError: name 'line' is not defined

# %%
#Word Tokenization

word_token = word_tokenize(text)

word_token
# Out:
# ['Reinforcement',
#  'Learning',
#  '(',
#  'RL',
#  ')',
#  'is',
#  'a',
#  'dynamic',
#  'and',
#  'powerful',
#  'branch',
#  'of',
#  'machine',
#  'learning',
#  'that',
#  'focuses',
#  'on',
#  'how',
#  'agents',
#  'ought',
#  'to',
#  'take',
#  'actions',
#  'in',
#  'an',
#  'environment',
#  'to',
#  'maximize',
#  'cumulative',
#  'rewards',
#  'over',
#  'time',
#  '.',
#  'Unlike',
#  'traditional',
#  'supervised',
#  'learning',
#  ',',
#  'where',
#  'models',
#  'are',
#  'trained',
#  'on',
#  'a',
#  'fixed',
#  'dataset',
#  'of',
#  'labeled',
#  'examples',
#  ',',
#  'RL',
#  'employs',
#  'a',
#  'trial-and-error',
#  'approach',
#  ',',
#  'allowing',
#  'agents',
#  'to',
#  'learn',
#  'from',
#  'their',
#  'experiences',
#  'through',
#  'interactions',
#  'with',
#  'the',
#  'environment',
#  '.',
#  'At',
#  'the',
#  'core',
#  'of',
#  'RL',
#  'is',
#  'the',
#  'concept',
#  'of',
#  'the',
#  'agent',
#  ',',
#  'which',
#  'observes',
#  'its',
#  'state',
#  ',',
#  'selects',
#  'actions',
#  ',',
#  'and',
#  'receives',
#  'feedback',
#  'in',
#  'the',
#  'form',
#  'of',
#  'rewards',
#  'or',
#  'penalties',
#  'based',
#  'on',
#  'the',
#  'outcomes',
#  'of',
#  'those',
#  'actions',
#  '.',
#  'The',
#  'framework',
#  'used',
#  'to',
#  'formalize',
#  'RL',
#  'problems',
#  'is',
#  'typically',
#  'the',
#  'Markov',
#  'Decision',
#  'Process',
#  '(',
#  'MDP',
#  ')',
#  ',',
#  'which',
#  'provides',
#  'a',
#  'mathematical',
#  'model',
#  'that',
#  'captures',
#  'the',
#  'environment',
#  "'s",
#  'dynamics',
#  ',',
#  'including',
#  'states',
#  ',',
#  'actions',
#  ',',
#  'transition',
#  'probabilities',
#  ',',
#  'and',
#  'reward',
#  'functions',
#  '.',
#  'The',
#  'goal',
#  'of',
#  'an',
#  'RL',
#  'agent',
#  'is',
#  'to',
#  'develop',
#  'a',
#  'policy—a',
#  'strategy',
#  'that',
#  'defines',
#  'the',
#  'best',
#  'action',
#  'to',
#  'take',
#  'in',
#  'each',
#  'state—to',
#  'optimize',
#  'long-term',
#  'rewards',
#  '.',
#  'This',
#  'involves',
#  'balancing',
#  'exploration',
#  '(',
#  'trying',
#  'new',
#  'actions',
#  'to',
#  'discover',
#  'their',
#  'effects',
#  ')',
#  'and',
#  'exploitation',
#  '(',
#  'selecting',
#  'known',
#  'actions',
#  'that',
#  'yield',
#  'high',
#  'rewards',
#  ')',
#  '.',
#  'Reinforcement',
#  'Learning',
#  'has',
#  'seen',
#  'significant',
#  'success',
#  'across',
#  'various',
#  'domains',
#  '.',
#  'In',
#  'gaming',
#  ',',
#  'algorithms',
#  'like',
#  'Deep',
#  'Q-Networks',
#  '(',
#  'DQN',
#  ')',
#  'have',
#  'enabled',
#  'agents',
#  'to',
#  'achieve',
#  'superhuman',
#  'performance',
#  'in',
#  'complex',
#  'games',
#  'such',
#  'as',
#  'Chess',
#  ',',
#  'Go',
#  ',',
#  'and',
#  'video',
#  'games',
#  '.',
#  'In',
#  'robotics',
#  ',',
#  'RL',
#  'techniques',
#  'empower',
#  'robots',
#  'to',
#  'learn',
#  'to',
#  'navigate',
#  'and',
#  'perform',
#  'tasks',
#  'in',
#  'unstructured',
#  'environments',
#  '.',
#  'Additionally',
#  ',',
#  'RL',
#  'is',
#  'increasingly',
#  'applied',
#  'in',
#  'areas',
#  'such',
#  'as',
#  'finance',
#  'for',
#  'algorithmic',
#  'trading',
#  ',',
#  'healthcare',
#  'for',
#  'personalized',
#  'treatment',
#  'plans',
#  ',',
#  'and',
#  'autonomous',
#  'vehicles',
#  'for',
#  'decision-making',
#  'in',
#  'real-time',
#  'traffic',
#  'situations',
#  '.',
#  'As',
#  'research',
#  'advances',
#  ',',
#  'RL',
#  'continues',
#  'to',
#  'evolve',
#  ',',
#  'addressing',
#  'challenges',
#  'such',
#  'as',
#  'sample',
#  'efficiency',
#  ',',
#  'scalability',
#  ',',
#  'and',
#  'generalization',
#  'to',
#  'create',
#  'more',
#  'robust',
#  'and',
#  'intelligent',
#  'agents',
#  'capable',
#  'of',
#  'operating',
#  'in',
#  'complex',
#  ',',
#  'real-world',
#  'scenarios',
#  '.']

# %%
#Remove Punctuations

def remove_punctuations(words):
  return [word for word in words if word not in string.punctuation]

clean = remove_punctuations(word_token)

clean
# Out:
# ['Reinforcement',
#  'Learning',
#  'RL',
#  'is',
#  'a',
#  'dynamic',
#  'and',
#  'powerful',
#  'branch',
#  'of',
#  'machine',
#  'learning',
#  'that',
#  'focuses',
#  'on',
#  'how',
#  'agents',
#  'ought',
#  'to',
#  'take',
#  'actions',
#  'in',
#  'an',
#  'environment',
#  'to',
#  'maximize',
#  'cumulative',
#  'rewards',
#  'over',
#  'time',
#  'Unlike',
#  'traditional',
#  'supervised',
#  'learning',
#  'where',
#  'models',
#  'are',
#  'trained',
#  'on',
#  'a',
#  'fixed',
#  'dataset',
#  'of',
#  'labeled',
#  'examples',
#  'RL',
#  'employs',
#  'a',
#  'trial-and-error',
#  'approach',
#  'allowing',
#  'agents',
#  'to',
#  'learn',
#  'from',
#  'their',
#  'experiences',
#  'through',
#  'interactions',
#  'with',
#  'the',
#  'environment',
#  'At',
#  'the',
#  'core',
#  'of',
#  'RL',
#  'is',
#  'the',
#  'concept',
#  'of',
#  'the',
#  'agent',
#  'which',
#  'observes',
#  'its',
#  'state',
#  'selects',
#  'actions',
#  'and',
#  'receives',
#  'feedback',
#  'in',
#  'the',
#  'form',
#  'of',
#  'rewards',
#  'or',
#  'penalties',
#  'based',
#  'on',
#  'the',
#  'outcomes',
#  'of',
#  'those',
#  'actions',
#  'The',
#  'framework',
#  'used',
#  'to',
#  'formalize',
#  'RL',
#  'problems',
#  'is',
#  'typically',
#  'the',
#  'Markov',
#  'Decision',
#  'Process',
#  'MDP',
#  'which',
#  'provides',
#  'a',
#  'mathematical',
#  'model',
#  'that',
#  'captures',
#  'the',
#  'environment',
#  "'s",
#  'dynamics',
#  'including',
#  'states',
#  'actions',
#  'transition',
#  'probabilities',
#  'and',
#  'reward',
#  'functions',
#  'The',
#  'goal',
#  'of',
#  'an',
#  'RL',
#  'agent',
#  'is',
#  'to',
#  'develop',
#  'a',
#  'policy—a',
#  'strategy',
#  'that',
#  'defines',
#  'the',
#  'best',
#  'action',
#  'to',
#  'take',
#  'in',
#  'each',
#  'state—to',
#  'optimize',
#  'long-term',
#  'rewards',
#  'This',
#  'involves',
#  'balancing',
#  'exploration',
#  'trying',
#  'new',
#  'actions',
#  'to',
#  'discover',
#  'their',
#  'effects',
#  'and',
#  'exploitation',
#  'selecting',
#  'known',
#  'actions',
#  'that',
#  'yield',
#  'high',
#  'rewards',
#  'Reinforcement',
#  'Learning',
#  'has',
#  'seen',
#  'significant',
#  'success',
#  'across',
#  'various',
#  'domains',
#  'In',
#  'gaming',
#  'algorithms',
#  'like',
#  'Deep',
#  'Q-Networks',
#  'DQN',
#  'have',
#  'enabled',
#  'agents',
#  'to',
#  'achieve',
#  'superhuman',
#  'performance',
#  'in',
#  'complex',
#  'games',
#  'such',
#  'as',
#  'Chess',
#  'Go',
#  'and',
#  'video',
#  'games',
#  'In',
#  'robotics',
#  'RL',
#  'techniques',
#  'empower',
#  'robots',
#  'to',
#  'learn',
#  'to',
#  'navigate',
#  'and',
#  'perform',
#  'tasks',
#  'in',
#  'unstructured',
#  'environments',
#  'Additionally',
#  'RL',
#  'is',
#  'increasingly',
#  'applied',
#  'in',
#  'areas',
#  'such',
#  'as',
#  'finance',
#  'for',
#  'algorithmic',
#  'trading',
#  'healthcare',
#  'for',
#  'personalized',
#  'treatment',
#  'plans',
#  'and',
#  'autonomous',
#  'vehicles',
#  'for',
#  'decision-making',
#  'in',
#  'real-time',
#  'traffic',
#  'situations',
#  'As',
#  'research',
#  'advances',
#  'RL',
#  'continues',
#  'to',
#  'evolve',
#  'addressing',
#  'challenges',
#  'such',
#  'as',
#  'sample',
#  'efficiency',
#  'scalability',
#  'and',
#  'generalization',
#  'to',
#  'create',
#  'more',
#  'robust',
#  'and',
#  'intelligent',
#  'agents',
#  'capable',
#  'of',
#  'operating',
#  'in',
#  'complex',
#  'real-world',
#  'scenarios']

# %%
#Stopwords Removal
swords = stopwords.words('english')

def remove_stopwords(clean_words):
  return [word for word in clean_words if word.lower() not in swords]

removed = remove_stopwords(clean)

# %%
print(removed)
# Out:
# ['Reinforcement', 'Learning', 'RL', 'dynamic', 'powerful', 'branch', 'machine', 'learning', 'focuses', 'agents', 'ought', 'take', 'actions', 'environment', 'maximize', 'cumulative', 'rewards', 'time', 'Unlike', 'traditional', 'supervised', 'learning', 'models', 'trained', 'fixed', 'dataset', 'labeled', 'examples', 'RL', 'employs', 'trial-and-error', 'approach', 'allowing', 'agents', 'learn', 'experiences', 'interactions', 'environment', 'core', 'RL', 'concept', 'agent', 'observes', 'state', 'selects', 'actions', 'receives', 'feedback', 'form', 'rewards', 'penalties', 'based', 'outcomes', 'actions', 'framework', 'used', 'formalize', 'RL', 'problems', 'typically', 'Markov', 'Decision', 'Process', 'MDP', 'provides', 'mathematical', 'model', 'captures', 'environment', "'s", 'dynamics', 'including', 'states', 'actions', 'transition', 'probabilities', 'reward', 'functions', 'goal', 'RL', 'agent', 'develop', 'policy—a', 'strategy', 'defines', 'best', 'action', 'take', 'state—to', 'optimize', 'long-term', 'rewards', 'involves', 'balancing', 'exploration', 'trying', 'new', 'actions', 'discover', 'effects', 'exploitation', 'selecting', 'known', 'actions', 'yield', 'high', 'rewards', 'Reinforcement', 'Learning', 'seen', 'significant', 'success', 'across', 'various', 'domains', 'gaming', 'algorithms', 'like', 'Deep', 'Q-Networks', 'DQN', 'enabled', 'agents', 'achieve', 'superhuman', 'performance', 'complex', 'games', 'Chess', 'Go', 'video', 'games', 'robotics', 'RL', 'techniques', 'empower', 'robots', 'learn', 'navigate', 'perform', 'tasks', 'unstructured', 'environments', 'Additionally', 'RL', 'increasingly', 'applied', 'areas', 'finance', 'algorithmic', 'trading', 'healthcare', 'personalized', 'treatment', 'plans', 'autonomous', 'vehicles', 'decision-making', 'real-time', 'traffic', 'situations', 'research', 'advances', 'RL', 'continues', 'evolve', 'addressing', 'challenges', 'sample', 'efficiency', 'scalability', 'generalization', 'create', 'robust', 'intelligent', 'agents', 'capable', 'operating', 'complex', 'real-world', 'scenarios']

# %%
#Stemming using PorterStemmer

def stemming(cleaned):
  return [ps.stem(stem) for stem in cleaned]

stemmed = stemming(removed)

# %%
stemmed
# Out:
# ['reinforc',
#  'learn',
#  'rl',
#  'dynam',
#  'power',
#  'branch',
#  'machin',
#  'learn',
#  'focus',
#  'agent',
#  'ought',
#  'take',
#  'action',
#  'environ',
#  'maxim',
#  'cumul',
#  'reward',
#  'time',
#  'unlik',
#  'tradit',
#  'supervis',
#  'learn',
#  'model',
#  'train',
#  'fix',
#  'dataset',
#  'label',
#  'exampl',
#  'rl',
#  'employ',
#  'trial-and-error',
#  'approach',
#  'allow',
#  'agent',
#  'learn',
#  'experi',
#  'interact',
#  'environ',
#  'core',
#  'rl',
#  'concept',
#  'agent',
#  'observ',
#  'state',
#  'select',
#  'action',
#  'receiv',
#  'feedback',
#  'form',
#  'reward',
#  'penalti',
#  'base',
#  'outcom',
#  'action',
#  'framework',
#  'use',
#  'formal',
#  'rl',
#  'problem',
#  'typic',
#  'markov',
#  'decis',
#  'process',
#  'mdp',
#  'provid',
#  'mathemat',
#  'model',
#  'captur',
#  'environ',
#  "'s",
#  'dynam',
#  'includ',
#  'state',
#  'action',
#  'transit',
#  'probabl',
#  'reward',
#  'function',
#  'goal',
#  'rl',
#  'agent',
#  'develop',
#  'policy—a',
#  'strategi',
#  'defin',
#  'best',
#  'action',
#  'take',
#  'state—to',
#  'optim',
#  'long-term',
#  'reward',
#  'involv',
#  'balanc',
#  'explor',
#  'tri',
#  'new',
#  'action',
#  'discov',
#  'effect',
#  'exploit',
#  'select',
#  'known',
#  'action',
#  'yield',
#  'high',
#  'reward',
#  'reinforc',
#  'learn',
#  'seen',
#  'signific',
#  'success',
#  'across',
#  'variou',
#  'domain',
#  'game',
#  'algorithm',
#  'like',
#  'deep',
#  'q-network',
#  'dqn',
#  'enabl',
#  'agent',
#  'achiev',
#  'superhuman',
#  'perform',
#  'complex',
#  'game',
#  'chess',
#  'go',
#  'video',
#  'game',
#  'robot',
#  'rl',
#  'techniqu',
#  'empow',
#  'robot',
#  'learn',
#  'navig',
#  'perform',
#  'task',
#  'unstructur',
#  'environ',
#  'addit',
#  'rl',
#  'increasingli',
#  'appli',
#  'area',
#  'financ',
#  'algorithm',
#  'trade',
#  'healthcar',
#  'person',
#  'treatment',
#  'plan',
#  'autonom',
#  'vehicl',
#  'decision-mak',
#  'real-tim',
#  'traffic',
#  'situat',
#  'research',
#  'advanc',
#  'rl',
#  'continu',
#  'evolv',
#  'address',
#  'challeng',
#  'sampl',
#  'effici',
#  'scalabl',
#  'gener',
#  'creat',
#  'robust',
#  'intellig',
#  'agent',
#  'capabl',
#  'oper',
#  'complex',
#  'real-world',
#  'scenario']
